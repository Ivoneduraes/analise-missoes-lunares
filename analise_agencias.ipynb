# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivoneduraes/analise-missoes-lunares/blob/analise-agencias/analise_agencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ivoneduraes/analise-missoes-lunares.git
# Out:
# Cloning into 'analise-missoes-lunares'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 5 (from 1)
# Receiving objects: 100% (6/6), 10.23 KiB | 5.12 MiB/s, done.

# %%
import pandas as pd
df_lua = pd.read_csv("/content/analise-missoes-lunares/Moonlanding.csv")
display(df_lua["Operator"].value_counts())
# Out:
# Operator
# United States NASA                   61
# Soviet Union Lavochkin               39
# Soviet Union OKB-1                   15
# China CNSA                           15
# Japan JAXA                            5
# India ISRO                            4
# Japan ISAS                            3
# European Union ESA                    2
# Tomy / JAXA / Doshisha University     2
# United States Hughes                  1
# United States USAF/NASA               1
# Japan United States ISAS/NASA         1
# United States USAF                    1
# Luxembourg LuxSpace                   1
# Israel SpaceIL                        1
# Italy ASI                             1
# South Korea KARI                      1
# United States Fluid & Reason          1
# Japan ispace                          1
# Japan Tomy/JAXA/Dodai                 1
# United States Lockheed Martin         1
# UAE UAESA/MBRSC                       1
# Russia Roscosmos                      1
# ...

# %%
display(df_lua["Operator"].value_counts().max())
# Out:
# 61
